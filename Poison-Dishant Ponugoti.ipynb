# %%
from my_module import functions

# %% [markdown]
# # Poison by Dishant Ponugoti
# My project is a video game based on the classic snake game. I discussed this with Griffin Goldberg, my classmate in COG18.
#
# I had borrowed his codes for the Snake Class, Grid Class and the Game_Manager Class with my own modifications in them. I had introduced the Poison function in it that also acts as an obstacle.
#
# In his he uses an AI that plays the game for the player while in mine it is a turn based game played by the player.
# One thing I did different to Griffin's orginal code is that the poison I added first appears and then continues to be appearing on the grid which forces the player to decide to keep track of what is poison and what is not poison.
#
# Also modifying parts of the code to facilitate the poison function I have also added the following original functions:
#     1. def spawn_Poison
#     2. def change_Char_P
#     3. def check_Ate_Poison
#     4. def p_Wait_Time

# %% [markdown]
# Below is a demonstration of Griffin's Snake Game with my Poison functions added. This example is used with a 6x6, however the game works with any size.

# %%
game_manager_1 = functions.game_manager()

game_manager_1.play_game()
# Out:
# 0
# @ * * * * *
# * P * * * *
# * * * * * *
# * * * F * *
# * * * * * *
# * * * * * *
# Enter w,a,s,d to move: d
# 0
# * @ * * * *
# * P * * * *
# * * * * * *
# * * * F * *
# * * * * * *
# * * * * * *
# Enter w,a,s,d to move: d
# 0
# * * @ * * *
# * P * * * *
# * * * * * *
# * * * F * *
# * * * * * *
# * * * * * *
# Enter w,a,s,d to move: d
# 0
# * * * @ * *
# * P * * * *
# * * * * * *
# * * * F * *
# * * * * * *
# * * * * * *
# Enter w,a,s,d to move: s
# 0
# * * * * * *
# * P * @ * *
# * * * * * *
# * * * F * *
# * * * * * *
# * * * * * *
# Enter w,a,s,d to move: s
# 0
# * * * * * *
# * P * * * *
# * * * @ * *
# * * * F * *
# * * * * * *
# * * * * * *
# Enter w,a,s,d to move: s
# 1
# * * * * * *
# * P * * * *
# * * * * * *
# * * * 0 * *
# * * * * * *
# * * * * * *
# Enter w,a,s,d to move: s
# 1
# * * * * F *
# * P * * * *
# * * * * * *
# * * * 0 * *
# * * * @ * *
# * * * * * *
# Enter w,a,s,d to move: a
# 1
# * * * * F *
# * P * * * *
# * * * * * *
# * * * * * *
# * * @ 0 * *
# ...
